# %%
print ("Hello")
# Out:
# Hello

# %%
a = 0
while a < 10:
    print ("Value of ",a)
    a += 1
# Out:
# Value of  0
# Value of  1
# Value of  2
# Value of  3
# Value of  4
# Value of  5
# Value of  6
# Value of  7
# Value of  8
# Value of  9

# %%
a = 0

while (a < 10):
    print("Current Value is",a)
    a += 1
    
else:
    print("Iteration over")
# Out:
# Current Value is 0
# Current Value is 1
# Current Value is 2
# Current Value is 3
# Current Value is 4
# Current Value is 5
# Current Value is 6
# Current Value is 7
# Current Value is 8
# Current Value is 9
# Iteration over

# %%
a = 0
while (a < 10):
    print("current value is",a)
    a += 1
    
    if (a == 5):
        print("I am ",a)
        break
# Out:
# current value is 0
# current value is 1
# current value is 2
# current value is 3
# current value is 4
# I am  5

# %%
a = 0

while (a<10):
    print("My Value is ",a)
    a += 1
    #break
    
else:
    print("Over")
            continue
# Out:
#   File "<ipython-input-14-394f5cde892e>", line 10
#     continue
#     ^
# IndentationError: unexpected indent

# %%
a = 0
while(a<10):
    print("Checking",a)
    a += 1
    
    if(a==7):
        print("Now it is",a)
        continue#break
    else:
        print("Hello it is not 7 but it is ",a)
        continue
# Out:
# Checking 0
# Hello it is not 7 but it is  1
# Checking 1
# Hello it is not 7 but it is  2
# Checking 2
# Hello it is not 7 but it is  3
# Checking 3
# Hello it is not 7 but it is  4
# Checking 4
# Hello it is not 7 but it is  5
# Checking 5
# Hello it is not 7 but it is  6
# Checking 6
# Now it is 7
# Checking 7
# Hello it is not 7 but it is  8
# Checking 8
# Hello it is not 7 but it is  9
# Checking 9
# Hello it is not 7 but it is  10

# %%
b = 0
while (b<1000):
    b += 1
    print("while looop value is ",b)
    
    if(b > 500):
        print ("Half",b)
        break
# Out:
# while looop value is  1
# while looop value is  2
# while looop value is  3
# while looop value is  4
# while looop value is  5
# while looop value is  6
# while looop value is  7
# while looop value is  8
# while looop value is  9
# while looop value is  10
# while looop value is  11
# while looop value is  12
# while looop value is  13
# while looop value is  14
# while looop value is  15
# while looop value is  16
# while looop value is  17
# while looop value is  18
# while looop value is  19
# while looop value is  20
# while looop value is  21
# while looop value is  22
# while looop value is  23
# while looop value is  24
# while looop value is  25
# while looop value is  26
# while looop value is  27
# while looop value is  28
# while looop value is  29
# while looop value is  30
# while looop value is  31
# while looop value is  32
# while looop value is  33
# while looop value is  34
# while looop value is  35
# while looop value is  36
# while looop value is  37
# ...
